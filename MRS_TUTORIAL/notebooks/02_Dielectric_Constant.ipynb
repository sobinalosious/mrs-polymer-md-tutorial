# %% [markdown]
# # Dielectric Constant from Dipole Fluctuations
#
# ## Theory Snapshot
#
# In polymer MD, the dipole component of the dielectric response can be estimated from fluctuations of the total dipole moment.
#
# This notebook focuses only on that dipolar contribution. It uses the MD dipole-fluctuation output to compute and visualize the dielectric response from sampling statistics.

# %%
from pathlib import Path
import sys

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from tutorial_config import DC_CONFIG
from tutorial_utils import run_dc_analysis

DC_CONFIG

# %% [markdown]
# This notebook is intentionally limited to the dipole component so the focus stays on the core fluctuation-based methodology.

# %%
dc_result = run_dc_analysis(
    root=ROOT,
    sample_name=DC_CONFIG["sample_name"],
    dipole_file=DC_CONFIG["dipole_file"],
    temperature_k=DC_CONFIG["temperature_k"],
)

dc_result["epsilon_dipole"]
