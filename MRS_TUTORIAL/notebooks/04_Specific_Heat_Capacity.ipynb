# %% [markdown]
# # Specific Heat Capacity from MD
#
# ## Theory Snapshot
#
# Specific heat capacity can be estimated from the temperature dependence of enthalpy.
#
# This notebook reads the prepared enthalpy-temperature dataset, performs block averaging, fits the enthalpy trend, and calculates Cp from the fitted slope.

# %%
from pathlib import Path
import sys

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from tutorial_config import CP_CONFIG
from tutorial_utils import run_cp_analysis

CP_CONFIG

# %% [markdown]
# The plot generated here shows both the raw enthalpy-temperature trend and the block-averaged fit used for the Cp estimate.

# %%
cp_result = run_cp_analysis(
    root=ROOT,
    sample_name=CP_CONFIG["sample_name"],
    cp_data_file=CP_CONFIG["cp_data_file"],
    num_blocks=CP_CONFIG["num_blocks"],
)

cp_result["cp_value"]
