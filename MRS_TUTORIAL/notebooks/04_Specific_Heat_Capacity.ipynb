# %% [markdown]
# # Specific Heat Capacity from MD
#
# ## Theory Snapshot
#
# Specific heat capacity can be estimated from the temperature dependence of enthalpy.
#
# In the full MD workflow, this is typically obtained from enthalpy-temperature data collected during the appropriate simulation stage. The current tutorial package includes a prepared Cp result file so the workflow overview can still include this property in the hands-on material.

# %%
from pathlib import Path
import sys

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from tutorial_config import CP_CONFIG
from tutorial_utils import run_cp_analysis

CP_CONFIG

# %% [markdown]
# This notebook currently uses the prepared Cp result file in the tutorial folder. If a raw enthalpy-temperature dataset is added later, this notebook can be extended to reproduce the line fit used to obtain Cp.

# %%
cp_result = run_cp_analysis(
    root=ROOT,
    sample_name=CP_CONFIG["sample_name"],
    cp_result_file=CP_CONFIG["cp_result_file"],
)

cp_result["cp_value"]
