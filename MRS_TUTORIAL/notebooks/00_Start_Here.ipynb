# %% [markdown]
# # Polymer MD Property Tutorial
#
# This workshop is analysis-only. No HPC access or LAMMPS setup is required to complete it.
#
# The notebooks use precomputed MD outputs to teach how three properties are extracted:
#
# - glass transition temperature
# - dielectric constant
# - thermal conductivity

# %% [markdown]
# ## How To Use This Tutorial
#
# 1. Run the setup cell.
# 2. Run the file-check cell.
# 3. Open the property notebooks in order.
#
# The notebooks save summary figures automatically into `../outputs/`.

# %%
from pathlib import Path
import sys

ROOT = Path("..").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from tutorial_utils import check_tutorial_setup
from tutorial_config import TG_CONFIG, DC_CONFIG, TC_CONFIG

print(f"Tutorial root: {ROOT}")
print("Loaded configs for TG, DC, and TC.")

# %%
status = check_tutorial_setup(ROOT)
status

# %% [markdown]
# ## Notebook Roadmap
#
# - `01_Glass_Transition_Temperature.ipynb`: density-temperature crossover and Tg fitting
# - `02_Dielectric_Constant.ipynb`: dipole fluctuations and dielectric response
# - `03_Thermal_Conductivity.ipynb`: heat flux, temperature gradient, and conductivity
#
# Before sharing the tutorial link publicly, review `tutorial_config.py` and confirm the PIDs and analysis settings.
